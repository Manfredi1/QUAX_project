# %%
import os
import scipy
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from scipy import optimize
from matplotlib.pyplot import cm
from lmfit import Model

# %% [markdown]
# ## User-defined functions

# %%
def load_dataset(path_folder,run):
    path=path_folder+"AnalyzedDataFFT_Run_"+str(run)+"_sliced.xlsx"
    meta = pd.read_excel(path,sheet_name=0,header=None)
    freq = pd.read_excel(path,sheet_name=1)[1]
    fft = pd.read_excel(path,sheet_name=2)
    
    data=pd.DataFrame({'freq':freq})
    
    columns=fft.columns
        
    j=0
    for column in columns[1:]:
        colname = 'fft' + str(run)+"_"+str(j)
        data[colname]=fft[column]
        
        j+=1
        
    cavity_freq=meta.iloc[3,1]
                
    return data,cavity_freq

# %%
def fit_run(path_folder,run,subrun=0):
    
    data,center=load_dataset("db/",run)
    
    def fitm(x,a,b,c,d,e,f):
        return e**2*abs(x-a+1j*b)**2/abs(x-c+1j*d)**2+f*(x-c)

    interval=data.copy()
    interval = data[(data['freq']>center-65100) & (data['freq']<center+65100)] # finestra di 200 bin ognuno da 651 Hz
    
    xfreq = interval['freq']
    fmin,fmax = min(xfreq),max(xfreq)
    
    yfft=interval.iloc[:,subrun+1]
    N=1.37e6
    
    #normalization ?
    #yfft=yfft*center**-1*3.5*1.38e-23*651/1e-24
    
    fmodel = Model(fitm)
    ps = fmodel.make_params(a=center, b=2e4, c=center,d=2.2e4,e=1e-2,f=1e-8)
    ps.add('a', value=center, min=center*0.999, max=center*1.01)
    ps.add('c', value=center, min=center*0.999, max=center*1.01)

    result = fmodel.fit(yfft,x=xfreq, 
                        params=ps,weights=yfft/np.sqrt(N))

    sigma=result.eval_uncertainty(x=xfreq)
    fig,ax=plt.subplots(1,2,figsize=(18,9))

    ax[0].scatter(xfreq,yfft,alpha=0.3)
    ax[0].vlines(center,0,6,'green',"dashed")
    ax[0].set_ylim([4.25e-5,6e-5])
    ax[0].set_xlim([fmin,fmax])
    ax[0].plot(xfreq,result.best_fit, label='linear model',color="red")
    ax[0].set_title("Fit result")

    ax[1].hist(result.residual/sigma)
    ax[1].set_title("Residuals")
    
    fig2,ax2=plt.subplots(1,1,figsize=(18,5))

    ax2.scatter(xfreq,result.residual,label="residuals")
    ax2.plot(xfreq,sigma,label="+$\sigma$")
    ax2.plot(xfreq,-sigma,label="-$\sigma$")
    ax2.set_xlim([fmin,fmax])
    ax2.set_title("Residuals vs freq")
    
    plt.show()
    
    return(result)

# %% [markdown]
# ## FIT RUN

# %%
fit_run("db/",389)
# Out:
# <h2> Model</h2> Model(fitm) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>43</td><td></td></tr><tr><td># data points</td><td>200</td><td></td></tr><tr><td># variables</td><td>6</td><td></td></tr><tr><td>chi-square</td><td> 5.0630e-28</td><td></td></tr><tr><td>reduced chi-square</td><td> 2.6098e-30</td><td></td></tr><tr><td>Akaike info crit.</td><td>-13617.7482</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-13597.9583</td><td></td></tr><tr><td>R-squared</td><td> 1.00000000</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> a </td><td>  1.0354e+10 </td><td>  116.773193 </td><td> (0.00%) </td><td> 10353522551.0 </td><td>  1.0343e+10 </td><td>  1.0457e+10 </td><td> True </td></tr><tr><td> b </td><td>  20842.0071 </td><td>  102.360313 </td><td> (0.49%) </td><td> 20000.0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> c </td><td>  1.0354e+10 </td><td>  126.052958 </td><td> (0.00%) </td><td> 10353522551.0 </td><td>  1.0343e+10 </td><td>  1.0457e+10 </td><td> True </td></tr><tr><td> d </td><td>  21962.9319 </td><td>  107.490336 </td><td> (0.49%) </td><td> 22000.0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> e </td><td>  0.00700689 </td><td>  6.6674e-07 </td><td> (0.01%) </td><td> 0.01 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> f </td><td> -8.2459e-12 </td><td>  2.7057e-13 </td><td> (3.28%) </td><td> 1e-08 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>b</td><td>d</td><td>+0.9997</td></tr><tr><td>a</td><td>c</td><td>+0.9996</td></tr><tr><td>c</td><td>f</td><td>-0.8428</td></tr><tr><td>a</td><td>f</td><td>-0.8293</td></tr><tr><td>d</td><td>e</td><td>+0.6436</td></tr><tr><td>b</td><td>e</td><td>+0.6275</td></tr><tr><td>b</td><td>f</td><td>-0.4663</td></tr><tr><td>d</td><td>f</td><td>-0.4580</td></tr><tr><td>b</td><td>c</td><td>+0.4227</td></tr><tr><td>a</td><td>b</td><td>+0.4123</td></tr><tr><td>c</td><td>d</td><td>+0.4120</td></tr><tr><td>a</td><td>d</td><td>+0.4016</td></tr><tr><td>a</td><td>e</td><td>-0.2492</td></tr><tr><td>c</td><td>e</td><td>-0.2403</td></tr><tr><td>e</td><td>f</td><td>+0.1037</td></tr></table>
